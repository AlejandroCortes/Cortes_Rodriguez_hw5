# %% [markdown]
# ### METODOS COMPUTACIONALES, TAREA 5, PUNTO 3

# %%
#importar librerias
# %pylab inline 
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft, fftfreq, fftshift
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#cargar archivo
data = np.loadtxt("circulos.dat")

# %%
#cargar datos de las posiciones x,y
x = data[:,0]
y = data[:,1]

# %%
#graficar los datos del archivo
fig = figure(1, figsize=(10,10))
plt.scatter(x, y, s=0.5, alpha=1)
plt.xlim([-3,3])
plt.ylim([-3,3])
plt.title('$Circulos$'' ''$y$'' ''$distribucion$'' ''$homogenea$',fontsize=20)
plt.xlabel('$Eje$'' ''$x$',fontsize=15)
plt.ylabel('$Eje$'' ''$x$',fontsize=15)

# %%
fig = figure(1, figsize=(10,10))
plt.hist2d(x,y,bins=(300,300))
plt.colorbar()
plt.title('$Histograma$'' ''$2D$'' ''$de$'' ''$los$'' ''$datos$',fontsize=(20))

# %%
#se debe hacer una rejilla fina, y determinar si dentro de los espacios de la rejilla quedan puntos o no. Para esto se toma
#el ancho del histograma o alto (6.0) y se divide sobre el numero de puntos que queremos que tenga la rejilla.


#número de puntos para dividir la rejilla, jaime menciono que para optimizar calculos debe ser una potencia de dos, en este caso
#escogimos 2^11 como numero elegido.

div_rej= 2048
ancho = 6.0
intervalo = ancho/div_rej

# %%
#ahora toca identificar si hay o no puntos dentro de cada espacio de la rejilla. Para esto se llenará una matriz de 1.0 y 0.0,
#donde 1.0 será si existen puntos dentro y 0.0 donde no haya nada.

#Se crea una matriz
rejilla = np.zeros((div_rej,div_rej))

for z in range(len(x)):
    X=x[z]
    Y=y[z]
    i=(X/intervalo)
    j=(Y/intervalo)
    rejilla[j,i]+= 1.0

# %%
trans = fft2(rejilla)
ortrans = fftshift(trans)

# %%
plt.imshow(((np.abs(ortrans))**2), cmap=cm.Greys_r)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x109ebc3f8>

# %% [markdown]
# Esta gráfica muestra que los valores son muy pequeños y planos, por lo tanto para poder ver algo se intentará sacar el logaritmo de los valores

# %%
plt.imshow(np.log((np.abs(ortrans))**2), cmap=cm.Greys_r)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x16c351518>

# %%
freq = fftfreq(div_rej, intervalo)

# %%
plt.plot(freq)
