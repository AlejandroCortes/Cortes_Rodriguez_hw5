# %%
#importar librerias
# %pylab inline 
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### METODOS COMPUTACIONALES, TAREA 5, PUNTO 1

# %% [markdown]
# ##### FILTROS PASA ALTAS Y PASA BAJAS EN IMAGENES

# %% [markdown]
# A continuación se realiza el filtrado de 4 señales bidimencionales (Imágenes) por medio de un filtro pasa bajas y otro pasa altas (frecuencias), usando la transformada de Fourier bidimensional en Python.

# %% [markdown]
# ##### El procedimiento realizado se describe acontinuación:

# %% [markdown]
# 1) Se carga la imagen incial y se mira el numero de capas que tiene cada imagen y de que tamaño son.
#
# 2) Se realiza la Transformada de fourier de la imagen.
#
# 3) Luego se divide la o las matrices en cuatro partes iguales para posteriormente cambiar su orden, como se muestra en la Figura 1.
#
# 4) Para aplicar cada uno de los filtros seleccionamos un circulo con centro en la mitad de la matriz. Si el filtro es pasa bajas los los valores que se encuentran ubicados dentro del circulo se convierten en 0. Pero, si el circulo es pasa altas los valores que estan fuera del cirulo se convierten en 0.
#
# 5) Para regresar a la nueva imagen tenemos que volver a organizar la matriz en las posiciones iniciales, es decir regresar el punto 3.
#
# 6) Aplicamos Transformada Inversa de Fourier a la matriz del punto 5.
#
# 7) Graficamos la imagen final.

# %%
im = plt.imread('transpuesta.png')
plt.imshow(im)
plt.title('$Figura$'' ''$1$')

# %% [markdown]
# ## FILTROS DE LA IMAGEN:  20_popc_cho009-1.tif

# %%
#Punto 1
#Carga y muestra la imagen 20_popc_cho009-1.tif
imagen1 = pylab.imread("Imagenes/20_popc_cho009-1.tif")
fig = figure(1, figsize=(8,8))
imshow(imagen1[:,:], cmap = cm.Greys_r)
plt.title('$IMAGEN$'' ''$ORIGINAL$', fontsize=20)

# %% [markdown]
# FILTRO PASA ALTAS

# %%
#Punto 2
#Usando la libreria de la Transformada de Fourier(TF) se halla la TF bidimensional 
#para la imagen (señal)
T1 = fft2(imagen1) 
#Imprime el tamaño de la matriz que es el resultado de la TF bidimensional
print np.shape(T1)
# Out:
# (560, 512)

# %% [markdown]
# Esta imagen tiene 560 pixeles de alto, 512 de largo y consta de 1 capa

# %%
#Punto 3
#Dividimos la matriz en cuatro partes iguales
A = T1[0:280,0:256]
B = T1[0:280,256:]
C = T1[280:,0:256]
D = T1[280:,256:]
print shape(A)
print shape(B)
print shape(C)
print shape(D)
# Out:
# (280, 256)
# (280, 256)
# (280, 256)
# (280, 256)

# %%
#Generamos una nueva matriz de zeros que recibe numeros complejos
T2 = np.zeros((560,512),dtype=complex)

#Llenamos la matriz con los valores de T1 pero en las nuevas posiciones
T2[0:280,0:256] = D
T2[0:280,256:] = C
T2[280:,0:256] = B
T2[280:,256:] = A

# %%
#COOOOOOOOOOO
hist2d(T2[1].real, T2[0].real)
# Out:
# (array([[  0.,   1.,   0.,   0.,   2.,   0.,   1.,   1.,   1.,   0.],
#         [  0.,   0.,   0.,   0.,   3.,   0.,   0.,   0.,   0.,   0.],
#         [  0.,   4.,   0.,   5.,   8.,   4.,   4.,   3.,   1.,   0.],
#         [  1.,   2.,   7.,   4.,  10.,   5.,   8.,   3.,   0.,   0.],
#         [  1.,   7.,  19.,  10.,  16.,  28.,  12.,   5.,   4.,   2.],
#         [  5.,   8.,  12.,  21.,  29.,  28.,  12.,   6.,   1.,   1.],
#         [  1.,   6.,  17.,  14.,  24.,  28.,  11.,   6.,   2.,   1.],
#         [  3.,   3.,   4.,   8.,  14.,  14.,  15.,   4.,   1.,   0.],
#         [  0.,   2.,   2.,   2.,   8.,   4.,   2.,   1.,   0.,   0.],
#         [  1.,   3.,   1.,   1.,   1.,   1.,   1.,   1.,   0.,   0.]]),
#  array([-15911.46833994, -13069.26978631, -10227.07123268,  -7384.87267905,
#          -4542.67412542,  -1700.47557179,   1141.72298184,   3983.92153548,
#           6826.12008911,   9668.31864274,  12510.51719637]),
# ...

# %%
#Convertimos en 0 todos los valores de la matriz T2 que se encuentran dentro de un circulo de 
#radio 100. centrado en el centro de la matriz, esto es un FILTRO PASA ALTAS
for j in range (560):
    for i in range (512):
        if (((i**2)-(256*i)+((-j)**2)+(280*j)) <= -14336):
            T2[j,i] = 0.0 + 0.0j

# %%
hist2d(T2[1].real, T2[0].real)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x135587cf8>

# %%
#Dividimos la matriz ya modificada nuevamente en cuatro partes iguales
E = T2[0:280,0:256]
F = T2[0:280,256:]
G = T2[280:,0:256]
H = T2[280:,256:]

# %%
#Generamos una matriz de ceros y la llenamos con los valores de la matriz T2 pero ahora en la posiciones iniciales
T3 = np.zeros((560,512),dtype=complex)


T3[0:280,0:256] = H
T3[0:280,256:] = G
T3[280:,0:256] = F
T3[280:,256:] = E


print np.shape(T3)
# Out:
# (560, 512)

# %%
#Hacemos la transformada inversa de la matriz T3 O T2, para recuperar la nueva imagen
T4 = ifft2(T3,axes=(0,1)).real
print np.shape(T4)
# Out:
# (560, 512)

# %%
#Ploteamos las nuevas imagenes despues de pasar por los filtros
fig = plt.figure(1,figsize=(8,8))
plt.imshow(T4-imagen1, cmap = cm.Greys_r)
plt.title('$FILTRO$'' ''$PASA$'' ''$ALTAS$',fontsize=20)

# %% [markdown]
# FILTRO PASA BAJAS

# %%
#Punto 2
#Usando la libreria de la Transformada de Fourier(TF) se halla la TF bidimensional 
#para la imagen (señal)
Q1 = fft2(imagen1) 
#Imprime el tamaño de la matriz que es el resultado de la TF bidimensional
print np.shape(Q1)
# Out:
# (560, 512)

# %%
#Punto 3
#Dividimos la matriz en cuatro partes iguales
AA = Q1[0:280,0:256]
BB = Q1[0:280,256:]
CC = Q1[280:,0:256]
DD = Q1[280:,256:]
print shape(AA)
print shape(BB)
print shape(CC)
print shape(DD)
# Out:
# (280, 256)
# (280, 256)
# (280, 256)
# (280, 256)

# %%
#Generamos una nueva matriz de zeros que recibe numeros complejos
Q2 = np.zeros((560,512),dtype=complex)

#Llenamos la matriz con los valores de T1 pero en las nuevas posiciones
Q2[0:280,0:256] = DD
Q2[0:280,256:] = CC
Q2[280:,0:256] = BB
Q2[280:,256:] = AA

# %%
#COOOOOOOOOOO
hist2d(Q2[1].real, Q2[0].real)
# Out:
# (array([[  0.,   1.,   0.,   0.,   2.,   0.,   1.,   1.,   1.,   0.],
#         [  0.,   0.,   0.,   0.,   3.,   0.,   0.,   0.,   0.,   0.],
#         [  0.,   4.,   0.,   5.,   8.,   4.,   4.,   3.,   1.,   0.],
#         [  1.,   2.,   7.,   4.,  10.,   5.,   8.,   3.,   0.,   0.],
#         [  1.,   7.,  19.,  10.,  16.,  28.,  12.,   5.,   4.,   2.],
#         [  5.,   8.,  12.,  21.,  29.,  28.,  12.,   6.,   1.,   1.],
#         [  1.,   6.,  17.,  14.,  24.,  28.,  11.,   6.,   2.,   1.],
#         [  3.,   3.,   4.,   8.,  14.,  14.,  15.,   4.,   1.,   0.],
#         [  0.,   2.,   2.,   2.,   8.,   4.,   2.,   1.,   0.,   0.],
#         [  1.,   3.,   1.,   1.,   1.,   1.,   1.,   1.,   0.,   0.]]),
#  array([-15911.46833994, -13069.26978631, -10227.07123268,  -7384.87267905,
#          -4542.67412542,  -1700.47557179,   1141.72298184,   3983.92153548,
#           6826.12008911,   9668.31864274,  12510.51719637]),
# ...

# %%
#Convertimos en 0 todos los valores de la matriz T2 que se encuentran dentro de un circulo de 
#radio 100. centrado en el centro de la matriz, esto es un FILTRO PASA ALTAS
for j in range (560):
    for i in range (512):
        if (((i**2)-(256*i)+((-j)**2)+(280*j)) > -14336):
            Q2[j,i] = 0.0 + 0.0j

# %%
hist2d(Q2[1].real, Q2[0].real)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11f103320>

# %%
#Dividimos la matriz ya modificada nuevamente en cuatro partes iguales
EE = Q2[0:280,0:256]
FF = Q2[0:280,256:]
GG = Q2[280:,0:256]
HH = Q2[280:,256:]

# %%
#Generamos una matriz de ceros y la llenamos con los valores de la matriz T2 pero ahora en la posiciones iniciales
Q3 = np.zeros((560,512),dtype=complex)


Q3[0:280,0:256] = HH
Q3[0:280,256:] = GG
Q3[280:,0:256] = FF
Q3[280:,256:] = EE


print np.shape(Q3)
# Out:
# (560, 512)

# %%
#Hacemos la transformada inversa de la matriz T3 O T2, para recuperar la nueva imagen
Q4 = ifft2(Q3,axes=(0,1)).real
print np.shape(Q4)
# Out:
# (560, 512)

# %%
#Ploteamos las nuevas imagenes despues de pasar por los filtros
fig = plt.figure(1,figsize=(8,8))
plt.imshow(Q4, cmap = cm.Greys_r)
plt.title('$FILTRO$'' ''$PASA$'' ''$ALTAS$',fontsize=20)

# %% [markdown]
# imagen1 = plt.imread('Imagenes/full_moon.jpg') #cargar imagen
# print shape(imagen1) #Muestra las dimensiones de la imagen
# plt.imshow(imagen1) #Muestra la imagen
